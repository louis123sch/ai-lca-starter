# %% [markdown]
# # 01 — Document to foreground inventory
# Prototype the extraction function here before relying on the Streamlit interface.

# %%
from ai_lca.llm import extract_inventory_from_text
from ai_lca.export import extraction_to_dataframe

# %%
text = '''
Paste a real paragraph/table transcription from a technical LCA source here.
Example: Electricity consumption is 52 kWh per kg of hydrogen produced.
'''

# %%
extraction = extract_inventory_from_text(
    text,
    extra_instructions='Keep infrastructure and operational inputs separate.'
)
extraction

# %%
extraction_to_dataframe(extraction)
